# %% [markdown]
# # Imports and Functions

# %%
import pandas as pd
import numpy as np
import spacy
import requests
import spacy_dbpedia_spotlight
from bs4 import BeautifulSoup
from geopy.distance import geodesic

# %%
def find_lat_long(raw_str):
    temp = raw_str.strip('POINT(').strip(')').split()
    lat = float(temp[0])
    long = float(temp[1])
    
    return lat, long

# %%
def centeroidnp(arr):
    length = arr.shape[0]
    sum_x = np.sum(arr[:, 0])
    sum_y = np.sum(arr[:, 1])
    
    return [sum_x/length, sum_y/length]

# %%
def find_shortest_geodistance(lat_long_list_1, lat_long_list_2):
    dist_list = []
    
    for c_i in lat_long_list_1:
        for c_j in lat_long_list_2:
            dist_list.append(geodesic(c_i, c_j))
            
    dist_list.sort()
    
    try:
        shortest = dist_list[0]
    except:
        shortest = None
        
    return shortest

# %% [markdown]
# # Load Data

# %%
df = pd.read_csv('./data/predicted_label_first_two_sentence_all_label.csv')

# %% [markdown]
# # DBpedia Spotlight for SpaCy

# %%
# load your model as usual
nlp = spacy.load('en_core_web_sm')
# add the pipeline stage
nlp.add_pipe('dbpedia_spotlight')

# %%
# get the document
doc = nlp('place of birth Taiwan')
# see the entities
print('Entities', [(ent.text, ent.label_, ent.kb_id_) for ent in doc.ents])
print('')
# inspect the raw data from DBpedia spotlight
print(doc.ents[0]._.dbpedia_raw_result)
# Out:
# Entities [('Taiwan', 'DBPEDIA_ENT', 'http://dbpedia.org/resource/Taiwan')]
#
# {'@URI': 'http://dbpedia.org/resource/Taiwan', '@support': '70226', '@types': 'Wikidata:Q6256,Schema:Place,Schema:Country,DBpedia:PopulatedPlace,DBpedia:Place,DBpedia:Location,DBpedia:Country', '@surfaceForm': 'Taiwan', '@offset': '15', '@similarityScore': '0.9997260518544173', '@percentageOfSecondRank': '1.2189605528416695E-4'}

# %%
# for i in range(len(doc.ents)):
#     print(doc.ents[i]._.dbpedia_raw_result)
#     print('')
    
# test_sentence = df.iloc[0]['raw_sentence']
# test_claim = df.iloc[0]['wikidata']
# test_entity_sentence = nlp(test_sentence)
# test_entity_claim = nlp(test_claim)

# print(test_entity_sentence.ents)
# print(test_claim)
# print(test_entity_sentence.ents[1]._.dbpedia_raw_result['@URI'])

# for i in range(len(test_entity_claim.ents)):
#     print(test_entity_claim.ents[i]._.dbpedia_raw_result)
#     print('')
    
# for i in range(len(test_entity_sentence.ents)):
#     print(test_entity_sentence.ents[i]._.dbpedia_raw_result)
#     print('')

# %% [markdown]
# # Task

# %% [markdown]
# ### Find Geo Points

# %%
df_0 = df.sort_values(by=['0_prob'], ascending=False)[:50]
df_1 = df.sort_values(by=['1_prob'], ascending=False)[:50]
df_0.reset_index(drop=True, inplace=True)
df_1.reset_index(drop=True, inplace=True)

# %%
centroid_sentence_0 = []
centroid_claim_0 = []
centroid_sentence_1 = []
centroid_claim_1 = []

# %%
# label = 0
# run through each sentence-claim pair
for i in range(len(df_0)):
    temp_sentence = df_0.iloc[i]['raw_sentence']
    temp_claim = df_0.iloc[i]['wikidata']
    temp_entity_sentence = nlp(temp_sentence)
    temp_entity_claim = nlp(temp_claim)
    temp_centroids_sentence = []
    temp_centroids_claim = []
    
    # run through all dbpedia entities in the sentence
    for j in range(len(temp_entity_sentence.ents)):
        # calculate the centroid of the place if the entity has latitude and longtitude information
        try:
            link = temp_entity_sentence.ents[j]._.dbpedia_raw_result['@URI']
            temp_source = requests.get(link)
            temp_soup_all = BeautifulSoup(temp_source.text, 'lxml')
            temp_list = []
            
            # find all geometry points
            for span in temp_soup_all.find_all('span', class_='literal'):
                try:
                    long, lat = find_lat_long(span.find('span', property="geo:geometry").text)
                    temp_list.append([lat, long])
                except:
                    continue
                    
            temp_array = np.asarray(temp_list)
            temp_centroids_sentence.append(centeroidnp(temp_array))
            
        except:
            continue
    centroid_sentence_0.append(temp_centroids_sentence)
    
    
    # run through all dbpedia entities in the claim
    for k in range(len(temp_entity_claim.ents)):
        # calculate the centroid of the place if the entity has latitude and longtitude information
        try:
            link = temp_entity_claim.ents[k]._.dbpedia_raw_result['@URI']
            temp_source = requests.get(link)
            temp_soup_all = BeautifulSoup(temp_source.text, 'lxml')
            temp_list = []
            
            # find all geometry points
            for span in temp_soup_all.find_all('span', class_='literal'):
                try:
                    long, lat = find_lat_long(span.find('span', property="geo:geometry").text)
                    temp_list.append([lat, long])
                except:
                    continue
                    
            temp_array = np.asarray(temp_list)
            temp_centroids_claim.append(centeroidnp(temp_array))
            
        except:
            continue
    centroid_claim_0.append(temp_centroids_claim)

# %%
df_0['sentence_centroid'] = centroid_sentence_0
df_0['claim_centroid'] = centroid_claim_0

# %%
# label = 1
# run through each sentence-claim pair
for i in range(len(df_1)):
    temp_sentence = df_1.iloc[i]['raw_sentence']
    temp_claim = df_1.iloc[i]['wikidata']
    temp_entity_sentence = nlp(temp_sentence)
    temp_entity_claim = nlp(temp_claim)
    temp_centroids_sentence = []
    temp_centroids_claim = []
    
    # run through all dbpedia entities in the sentence
    for j in range(len(temp_entity_sentence.ents)):
        # calculate the centroid of the place if the entity has latitude and longtitude information
        try:
            link = temp_entity_sentence.ents[j]._.dbpedia_raw_result['@URI']
            temp_source = requests.get(link)
            temp_soup_all = BeautifulSoup(temp_source.text, 'lxml')
            temp_list = []
            
            # find all geometry points
            for span in temp_soup_all.find_all('span', class_='literal'):
                try:
                    long, lat = find_lat_long(span.find('span', property="geo:geometry").text)
                    temp_list.append([lat, long])
                except:
                    continue
                    
            temp_array = np.asarray(temp_list)
            temp_centroids_sentence.append(centeroidnp(temp_array))
            
        except:
            continue
    centroid_sentence_1.append(temp_centroids_sentence)
    
    
    # run through all dbpedia entities in the claim
    for k in range(len(temp_entity_claim.ents)):
        # calculate the centroid of the place if the entity has latitude and longtitude information
        try:
            link = temp_entity_claim.ents[k]._.dbpedia_raw_result['@URI']
            temp_source = requests.get(link)
            temp_soup_all = BeautifulSoup(temp_source.text, 'lxml')
            temp_list = []
            
            # find all geometry points
            for span in temp_soup_all.find_all('span', class_='literal'):
                try:
                    long, lat = find_lat_long(span.find('span', property="geo:geometry").text)
                    temp_list.append([lat, long])
                except:
                    continue
                    
            temp_array = np.asarray(temp_list)
            temp_centroids_claim.append(centeroidnp(temp_array))
            
        except:
            continue
    centroid_claim_1.append(temp_centroids_claim)
# Out:
# 146 161 {'@URI': 'http://dbpedia.org/resource/John_Meyendorff', '@support': '64', '@types': '', '@surfaceForm': 'John Meyendorff', '@offset': '146', '@similarityScore': '1.0', '@percentageOfSecondRank': '0.0'}

# %%
df_1['sentence_centroid'] = centroid_sentence_1
df_1['claim_centroid'] = centroid_claim_1

# %% [markdown]
# ### Find Shortest

# %%
shortest_0_list = []

for i in range(len(df_0)):
    temp_list_i = df_0.iloc[i]['sentence_centroid']
    temp_list_j = df_0.iloc[i]['claim_centroid']
    shortest_0_list.append(find_shortest_geodistance(temp_list_i, temp_list_j))
    
df_0['shortest'] = shortest_0_list

# %%
shortest_1_list = []

for i in range(len(df_1)):
    temp_list_i = df_1.iloc[i]['sentence_centroid']
    temp_list_j = df_1.iloc[i]['claim_centroid']
    shortest_1_list.append(find_shortest_geodistance(temp_list_i, temp_list_j))
    
df_1['shortest'] = shortest_1_list

# %%
df_0
# Out:
#                                              sentence  \
# 0   he was born in blue island, illinois, raised i...
# 1   dong yu (chinese: 董宇; born 15 july 1994 in qin...
# 2   elisabeth clara heath-sladen (1 february 1946s...
# 3   fløgstad was born in the industrial city of sa...
# 4   he was born 10 december 1934 at yunlin county ...
# 5   he was born in yilan, taiwan.lan cheng-lung at...
# 6   1786 – 11 march 1870) was born at menkhoaneng ...
# 7   edward ou () was born on 16 october 1980 in ta...
# 8   frank johnson goodnow (january 18, 1859 – nove...
# 9   samir brahimi is an algerian boxer born on 17 ...
# 10                  he was born in changzhou, jiangsu
# 11  chang was born in chongqing in 1944 and grew u...
# 12  she was born in the shanxi province to parents...
# 13  he was born in 1899 in ichikawa, chiba prefecture
# 14                              vian was born in rome
# 15  barbara mittler (born 15 february 1968 in hage...
# 16   is a japanese anime director, born on october...
# 17  born in sarawak, chua moved to kuala lumpur to...
# 18                      he was born in xiaoyi, shanxi
# 19                             levieva was born in st
# 20        he was born on 31 october 1937 in karlsruhe
# 21  pál losonczi (born as pál laklia; 18 september...
# 22  ram kapoor (; born 1 september 1973) is an ind...
# 23  kōki ishii (石井 紘基 ishii kōki, november 6, 1940...
# 24               mattila was born in tampere, finland
# 25  he was born and raised in the north end of win...
# 26  born in bellflower, california, carter graduat...
# 27  mahendra was born in june 11, 1920 to king tri...
# 28  he was born in 1415 as prince vong buri, the y...
# 29  chan was born in china in 1901 and went to the...
# 30  wen kezheng (, 1929–2007) was a famous chinese...
# 31  born in baku to a revolutionary and friend of ...
# 32  he was born in a small jiangsu (now in suzhou,...
# 33                 he was born in luang prabang, laos
# 34         she was born in pusan, south korea in 1947
# 35  huang poren (; born 1970), a taiwanese sculpto...
# 36                      he was jewish, born in vienna
# 37  lowell liebermann (born february 22, 1961 in n...
# 38  born in puerto rico, báez attended high school...
# 39  mette schjoldager (born 21 april 1977) is a da...
# 40  carlos montez melancia (born 21 august 1927) w...
# 41  hesse was born in königsberg, prussia, and die...
# 42  hu xiaolian (; born 1958) is the deputy govern...
# 43  heinrich, prince of fürstenberg (heinrich fürs...
# 44  milena markovna "mila" kunis (; ukrainian: міл...
# 45  stefano baldini (born 25 may 1971 in castelnov...
# 46  wang gungwu,  (; born 9 october 1930) is an au...
# 47    he was born in pingding county, shanxi province
# 48            hopkins was born in lexington, kentucky
# 49  viktor franzovich zhdanovich () (born on janua...
#
#                                wikidata  label  \
# 0            place of birth Tinley Park    NaN
# 1                place of birth Qingdao    NaN
# 2              place of birth Liverpool    NaN
# 3                  place of birth Sauda    NaN
# 4        place of birth Beigang, Yunlin    NaN
# 5                place of birth Luodong    NaN
# 6                place of birth Lesotho    NaN
# 7                 place of birth Taiwan    NaN
# 8               place of birth Brooklyn    NaN
# 9                place of birth Algiers    NaN
# 10             place of birth Changzhou    NaN
# 11             place of birth Chongqing    NaN
# 12               place of birth Taiyuan    NaN
# 13      place of birth Chiba Prefecture    NaN
# 14                  place of birth Rome    NaN
# 15                 place of birth Hagen    NaN
# 16      place of birth Chiba Prefecture    NaN
# 17               place of birth Kuching    NaN
# 18                place of birth Xiaoyi    NaN
# 19      place of birth Saint Petersburg    NaN
# 20             place of birth Karlsruhe    NaN
# 21                 place of birth Bolhó    NaN
# 22             place of birth New Delhi    NaN
# 23           place of birth Setagaya-ku    NaN
# 24               place of birth Tampere    NaN
# 25              place of birth Winnipeg    NaN
# 26            place of birth Bellflower    NaN
# 27             place of birth Kathmandu    NaN
# 28         place of birth Luang Prabang    NaN
# 29               place of birth Kaiping    NaN
# 30               place of birth Beijing    NaN
# 31               place of birth Tbilisi    NaN
# 32               place of birth Jiangsu    NaN
# 33         place of birth Luang Prabang    NaN
# 34                 place of birth Busan    NaN
# 35              place of birth Taichung    NaN
# 36                place of birth Vienna    NaN
# 37         place of birth New York City    NaN
# 38               place of birth Bayamón    NaN
# 39                  place of birth Viby    NaN
# 40     place of birth Santarém District    NaN
# 41            place of birth Königsberg    NaN
# 42                 place of birth Hubei    NaN
# 43  place of birth Schloss Heiligenberg    NaN
# 44            place of birth Chernivtsi    NaN
# 45   place of birth Castelnovo di Sotto    NaN
# 46              place of birth Surabaya    NaN
# 47       place of birth Pingding County    NaN
# 48             place of birth Lexington    NaN
# 49      place of birth Saint Petersburg    NaN
#
#                                          raw_sentence    0_prob    1_prob  \
# 0   He was born in Blue Island, Illinois, raised i...  0.989592  0.004328
# 1   Dong Yu (Chinese: 董宇; born 15 July 1994 in Qin...  0.988216  0.003877
# 2   Elisabeth Clara Heath-Sladen (1 February 1946S...  0.987689  0.004745
# 3   Fløgstad was born in the industrial city of Sa...  0.987566  0.006371
# 4   He was born 10 December 1934 at Yunlin County ...  0.987284  0.005804
# 5   He was born in Yilan, Taiwan.Lan Cheng-lung at...  0.987240  0.004438
# 6   1786 – 11 March 1870) was born at Menkhoaneng ...  0.987205  0.005485
# 7   Edward Ou () was born on 16 October 1980 in Ta...  0.987157  0.002633
# 8   Frank Johnson Goodnow (January 18, 1859 – Nove...  0.987102  0.004501
# 9   Samir Brahimi is an Algerian boxer born on 17 ...  0.987089  0.004305
# 10                  He was born in Changzhou, Jiangsu  0.987029  0.006401
# 11  Chang was born in Chongqing in 1944 and grew u...  0.987019  0.005340
# 12  She was born in the Shanxi Province to parents...  0.986915  0.005571
# 13  He was born in 1899 in Ichikawa, Chiba Prefecture  0.986904  0.004307
# 14                              Vian was born in Rome  0.986793  0.004571
# 18  rafael edward cruz (; born december 22, 1970) ...
# 19  diego klattenhoff (born november 30, 1979) is ...
# 20  lim yong-kyu (born june 18, 1991) is a profess...
# 21  michele polverino (born 26 september 1984) is ...
# 22  matteo elias kenzo guendouzi olié (; born 14 a...
# 23  jean rhys,  (; born ella gwendolyn rees willia...
# 24  caolan owen lavery (born 22 october 1992) is a...
# 25  chiu ching-chun (; born 8 december 1949) is a ...
# 26  alex caruso (born february 28, 1994) is an ame...
# 27  john david douglas (born june 12, 1956) is a r...
# 28  stuart antony alan o'keefe (born 4 march 1991)...
# 29  marat zhaksylykuly abiyev (, marat jaqsylyquly...
# 30  , born  is a japanese comedian, impressionist,...
# 31  abbé fulbert youlou (29 june,in african powder...
# 32  jean-baptiste-camille corot ( ,  , ; july 16, ...
# 33  juan moreno y herrera–jiménez (born 30 july 19...
# 34  anthony mark mowbray (born 22 november 1963) i...
# 35  tomohito ito (伊藤 智仁, born october 30, 1970) is...
# 36   (born january 24, 1951) is a japanese vocalis...
# 37  mayumi wakamura (若村麻由美 wakamura mayumi, born o...
# 38  marianne vos (; born 13 may 1987) is a dutch c...
# 39  karim alami () (born 24 may 1973) is a retired...
# 40   (born december 17, 1984) is a japanese pop si...
# 41  elie wiesel (, born eliezer wiesel  ʾĕlîʿezer ...
# 42  yang yun (), born october 6, 1988), is a chine...
# 43  he is most famous in the french-speaking world...
# 44  sarah elizabeth hughes (born may 2, 1985) is a...
# 45  (born may 30, 1965) is an american professiona...
# 46  masami yokoyama (横山雅美 yokoyama masami, born de...
# 47  bartholomew i (, , ; born 29 february 1940) is...
# 48  james french hill (born december 5, 1956) is a...
# 49  steven gerald clifford (born september 17, 196...
#
#                                       wikidata  label  \
# 0                       place of birth ouedjda    NaN
# 1                       place of birth ouedjda    NaN
# 2                       place of birth ouedjda    NaN
# 3                       place of birth Teaneck    NaN
# 4                     place of birth fenghuang    NaN
# 5                           place of birth Egg    NaN
# 6                        place of birth Liling    NaN
# 7            place of birth Shri gurusar modia    NaN
# 8              place of birth 's-Hertogenbosch    NaN
# 9                   place of birth Harbor City    NaN
# 10                   place of birth Bellflower    NaN
# 11             place of birth 's-Hertogenbosch    NaN
# 12                      place of birth Arborea    NaN
# 13                    place of birth Collioure    NaN
# 14                         place of birth Bree    NaN
# 15                     place of birth Fountain    NaN
# 16                       place of birth Gurupi    NaN
# 17                   place of birth casablanca    NaN
# 18     place of birth Foothills Medical Centre    NaN
# 19  place of birth French River, Pictou County    NaN
# 20                       place of birth Andong    NaN
# 21                        place of birth Grabs    NaN
# 22                       place of birth Poissy    NaN
# 23                       place of birth Roseau    NaN
# 24                     place of birth Red Deer    NaN
# 25                         place of birth Emei    NaN
# 26              place of birth College Station    NaN
# 27                   place of birth Town Creek    NaN
# 28                          place of birth Eye    NaN
# 29                   place of birth Kandyagash    NaN
# 30                      place of birth Kita-ku    NaN
# 31              place of birth Pool Department    NaN
# 32                   place of birth rue du Bac    NaN
# 33                   place of birth casablanca    NaN
# 34          place of birth Saltburn-by-the-Sea    NaN
# 35                   place of birth Nakagyō-ku    NaN
# 36                    place of birth Nakano-ku    NaN
# 37                    place of birth Nerima-ku    NaN
