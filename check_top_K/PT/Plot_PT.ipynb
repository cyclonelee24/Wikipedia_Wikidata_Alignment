# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
from bokeh.plotting import ColumnDataSource, figure, output_file, show
from bokeh.io import output_notebook

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Load Data

# %%
df = pd.read_pickle('first_two_sentences_EN_and_PT_POB.pkl')
df_PT = pd.read_csv('PT_result.csv', index_col=[0])
df_EN = pd.read_csv('EN_result.csv', index_col=[0])

# %%
PT_0_prob = df_PT['0_prob']
PT_1_prob = df_PT['1_prob']
PT_2_prob = df_PT['2_prob']
EN_0_prob = df_EN['0_prob']
EN_1_prob = df_EN['1_prob']
EN_2_prob = df_EN['2_prob']

# %%
Wikidata_PT = df_PT['wikidata']
Wikidata_EN = df_EN['wikidata']

# %%
df['PT_0_prob'] = PT_0_prob
df['PT_1_prob'] = PT_1_prob
df['PT_2_prob'] = PT_2_prob

# %%
df['EN_0_prob'] = EN_0_prob
df['EN_1_prob'] = EN_1_prob
df['EN_2_prob'] = EN_2_prob

# %%
df['Wikidata_PT'] = Wikidata_PT
df['Wikidata_EN'] = Wikidata_EN

# %%
print(df.shape)
# Out:
# (30002, 11)

# %%
df.head()
# Out:
#          Qid                                        sentence_EN  \
# 0   Q1015531  ludmila manicler born 6 july 1987 is an argent...
# 1   Q1050388  was a japanese general who served during the s...
# 2  Q10526787  is a japanese football player currently playin...
# 3    Q105695  annasophia robb born december 8, 1993 is an am...
# 4   Q1087146  christos dimitriou papakyriakopoulos , commonl...
#
#                                          sentence_PT  PT_0_prob  PT_1_prob  \
# 0   ludmila manicler 6 de julho de 1987 é uma fut...   0.015466   0.829742
# 1    foi um general do exército imperial japonês ...   0.002883   0.009499
# 2   wataru endo ibaraki, 9 de fevereiro de 1993 é...   0.004639   0.986745
# 3   annasophia robb denver, colorado, 8 de dezemb...   0.691228   0.009083
# 4   christos dimitriou papakyriakopoulos, mais co...   0.875275   0.007232
#
#    PT_2_prob  EN_0_prob  EN_1_prob  EN_2_prob  \
# 0   0.154792   0.961972   0.008174   0.029854
# 1   0.987618   0.000720   0.000418   0.998862
# 2   0.008616   0.000745   0.000572   0.998683
# 3   0.299689   0.907669   0.017064   0.075267
# 4   0.117493   0.965165   0.007697   0.027139
#
#                                     Wikidata_PT               Wikidata_EN
# 0  local de nascimento San Pedro (Buenos Aires)  place of birth San Pedro
# 1                 local de nascimento Kagoshima  place of birth Kagoshima
# 2                   local de nascimento Iocoama   place of birth Yokohama
# 3                    local de nascimento Denver     place of birth Denver
# 4                    local de nascimento Atenas     place of birth Athens

# %% [markdown]
# # Plot

# %%
output_file("EN_PT_inconsistent_Prob_Plot.html")

source = ColumnDataSource(data=dict(
    x=df['PT_1_prob'],
    y=df['EN_1_prob'],
    desc=df['Qid'],
))

TOOLTIPS = [
    ("index", "$index"),
    ("(x,y)", "($x, $y)"),
    ("desc", "@desc"),
]

p = figure(plot_width=2000, plot_height=2000, tooltips=TOOLTIPS, title="EN_PT_inconsistent_Prob_Plot")
p.xaxis.axis_label = 'PT_inconsistent_prob'
p.yaxis.axis_label = 'EN_inconsistent_prob'

p.circle('x', 'y', size=3, source=source)
# Out:
# GlyphRenderer(id='1041', ...)

# %%
show(p)
# Out:
#   <div class="bk-root" id="a64c4cf7-87b6-4617-8b1e-9d36f09925ea" data-root-id="1003"></div>

# %%
output_file("EN_PT_consistent_Prob_Plot.html")

source = ColumnDataSource(data=dict(
    x=df['PT_0_prob'],
    y=df['EN_0_prob'],
    desc=df['Qid'],
))

TOOLTIPS = [
    ("index", "$index"),
    ("(x,y)", "($x, $y)"),
    ("desc", "@desc"),
]

p0 = figure(plot_width=2000, plot_height=2000, tooltips=TOOLTIPS, title="EN_PT_consistent_Prob_Plot")
p0.xaxis.axis_label = 'PT_consistent_prob'
p0.yaxis.axis_label = 'EN_consistent_prob'

p0.circle('x', 'y', size=3, source=source)
# Out:
# GlyphRenderer(id='1205', ...)

# %%
show(p0)
# Out:
#   <div class="bk-root" id="e9acc041-0d48-4ac2-9185-acdbe1a72e06" data-root-id="1167"></div>

# %%
output_file("EN_PT_irrelevant_Prob_Plot.html")

source = ColumnDataSource(data=dict(
    x=df['PT_2_prob'],
    y=df['EN_2_prob'],
    desc=df['Qid'],
))

TOOLTIPS = [
    ("index", "$index"),
    ("(x,y)", "($x, $y)"),
    ("desc", "@desc"),
]

p2 = figure(plot_width=2000, plot_height=2000, tooltips=TOOLTIPS, title="EN_PT_irrelevant_Plot")
p2.xaxis.axis_label = 'PT_irrelevant_prob'
p2.yaxis.axis_label = 'EN_irrelevant_prob'

p2.circle('x', 'y', size=3, source=source)
# Out:
# GlyphRenderer(id='1393', ...)

# %%
show(p2)
# Out:
#   <div class="bk-root" id="1d41e868-48c2-4c50-a8db-ff9b8018c0e4" data-root-id="1355"></div>

# %% [markdown]
# #

# %%
df_PT_prob = df[['PT_0_prob', 'PT_1_prob', 'PT_2_prob']].to_numpy()
df_EN_prob = df[['EN_0_prob', 'EN_1_prob', 'EN_2_prob']].to_numpy()

# %%
pred_PT = np.argmax(df_PT_prob, axis=1)
pred_EN = np.argmax(df_EN_prob, axis=1)

# %%
labels_PT, counts_PT = np.unique(pred_PT, return_counts=True)
print("Frequency of label of PT:")
print(np.asarray((labels_PT, counts_PT)))
# Out:
# Frequency of label of PT:
# [[    0     1     2]
#  [17649  8022  4331]]

# %%
labels_EN, counts_EN = np.unique(pred_EN, return_counts=True)
print("Frequency of label of EN:")
print(np.asarray((labels_EN, counts_EN)))
# Out:
# Frequency of label of EN:
# [[    0     1     2]
#  [18769    93 11140]]

# %%
df.to_pickle('Final_result_EN_PT.pkl')

# %% [markdown]
# # Check Top K

# %%
df.sort_values(by='PT_1_prob', axis=0, ascending=False)
# Out:
#            Qid                                        sentence_EN  \
# 24830  Q552925  arlo davy guthrie born july 10, 1947 is an ame...
# 29458  Q204018  jermaine lamarr cole born january 28, 1985 is ...
# 668    Q390491  roger frederick wicker born july 5, 1951 is an...
# 570    Q881196  paul richard lepage ; born october 9, 1948 is ...
# 12443  Q381880  sherrod campbell brown , born november 9, 1952...
# ...        ...                                                ...
# 19218  Q378003  david da-i ho ; born november 3, 1952 is a tai...
# 21332  Q317947  crates gave away his money to live a life of p...
# 12455  Q470531  encyclopaedia of the history of science, techn...
# 11905  Q725400  july 21, 1929 – july 16, 2006 was an american ...
# 11816  Q233950  daniel kahneman ; ; born march 5, 1934 is an i...
#
#                                              sentence_PT  PT_0_prob  \
# 24830   thumb|right|250px|o músico em 2007 thumb|righ...   0.004106
# 29458   jermaine lamarr cole frankfurt, , mais conhec...   0.003926
# 668     200px|thumb|roger frederick wicker em foto of...   0.003910
# 570     200px|thumb|paul lepage paul r lepage nascido...   0.003787
# 12443   200px|thumb|sherrod brown sherrod campbell br...   0.003652
# ...                                                  ...        ...
# 19218   david da-i ho ; 3 de novembro de 1952sen russ...   0.003036
# 21332   crates ; c 365 – c 285 bctiziano dorandi, cha...   0.002927
# 12455   ,selin, helaine 1997 encyclopaedia of the his...   0.003238
# 11905   se quiser ver o filho de bob orton, sr consul...   0.002230
# 11816   daniel kahneman tel aviv,  é um teórico da ec...   0.008496
#
#        PT_1_prob  PT_2_prob  EN_0_prob  EN_1_prob  EN_2_prob  \
# 24830   0.992869   0.003025   0.387842   0.071424   0.540734
# 29458   0.992803   0.003270   0.962977   0.008027   0.028996
# 668     0.992709   0.003381   0.963770   0.008068   0.028162
# 570     0.992706   0.003506   0.966344   0.008210   0.025446
# 12443   0.992694   0.003654   0.965382   0.007710   0.026907
# ...          ...        ...        ...        ...        ...
# 19218   0.002548   0.994415   0.960661   0.007806   0.031533
# 21332   0.002513   0.994559   0.000895   0.000383   0.998723
# 12455   0.002485   0.994277   0.000770   0.000555   0.998676
# 11905   0.002437   0.995333   0.000691   0.000387   0.998922
# 11816   0.002429   0.989075   0.952512   0.007702   0.039786
#
#                                    Wikidata_PT  \
# 24830         local de nascimento Coney Island
# 29458  local de nascimento Francoforte do Meno
# 668               local de nascimento Pontotoc
# 570               local de nascimento Lewiston
# 12443            local de nascimento Mansfield
# ...                                        ...
# 19218             local de nascimento Taichung
# 21332                local de nascimento Tebas
# 12455              local de nascimento Fujioka
# 11905          local de nascimento Kansas City
# 11816        local de nascimento Tel aviv-yafo
#
#                             Wikidata_EN
# 24830       place of birth Coney Island
# 29458  place of birth Frankfurt am Main
# 668             place of birth Pontotoc
# 570             place of birth Lewiston
# 12443          place of birth Mansfield
# ...                                 ...
# 19218           place of birth Taichung
# 21332             place of birth Thebes
# 12455            place of birth Fujioka
# 11905        place of birth Kansas City
# 11816           place of birth Tel Aviv
#
# [30002 rows x 11 columns]
